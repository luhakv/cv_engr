# %% [markdown]
# ## Трек «CV-инженер»
# ### Skillfactory: DSPR-19
# ### Модуль 2. Математика для нейронных сетей. Часть I

# %% [markdown]
# ### 1. Что вас ждёт в этом модуле?
#
# ⛏ Теперь, когда вы освоили базовые знания о глубоком обучении и специфику работы с данными в NLP, вы готовы приступить к теме «Математика в нейронных сетях».
#
# Эта тема будет состоять из двух модулей и включать в себя как математические задачи, так и задачи на программирование.
# Многое из того, что мы изучим, уже знакомо вам из базового курса по математике, но на этот раз мы посмотрим на те же темы в контексте глубокого обучения.
# Мы посмотрим:
# - что находится «под капотом» нейронных сетей;
# - как они устроены изнутри;
# - что из себя представляет процесс их обучения с точки зрения математики.
#
# #### В ЭТОМ МОДУЛЕ МЫ РАЗБЕРЁМ:
#
# - как устроена линейная регрессия;
#
# - чем градиентный спуск хорош для обучения;
#
# - что такое функции потерь и какова их математика;
#
# - какова связь линейных моделей с нейронами и нейросетями.
#
# #### ВЫ НАУЧИТЕСЬ:
#
# - писать линейную модель и отдельный нейрон на NumPy;
#
# - вручную считать градиенты для градиентного спуска;
#
# - разбираться в особенностях функций потерь для различных задач.
#
# В конце данного модуля вы решите задачу классификации без использования верхнеуровневых библиотек для глубокого обучения.
#
# - Вы можете спросить: зачем это нужно, если мы можем взять и воспользоваться готовыми библиотеками для обучения?
#
# Понимание внутреннего устройства даёт вам возможность быть более гибкими, вносить свои изменения в модели и их обучение. Оно позволит понять, в какую сторону можно и нужно двигаться при столкновении с трудностями, придумывать свои архитектуры или изменять существующие, а также работать с разными типами данных, в том числе нестандартными, и проводить исследования более осознанно, что точно будет полезно в работе дата-сайентиста и даст вам преимущество на рынке.
#
# #### МАТЕРИАЛЫ МОДУЛЯ ПОДГОТОВИЛИ:
#
#
# ГРИГОРИЙ АЛЕКСЕЕНКО
#
# Ведущий разработчик отдела систем компьютерного зрения, Axxonsoft
#
# ### 2. Вспоминаем NumPy
#
# ⛏ Для того чтобы глубже разобраться в том, как всё устроено, в этом модуле мы будем использовать только NumPy-библиотеку и реализовывать модели своими руками. Так мы лучше поймём, что находится внутри и на каких математических предположениях строятся данные модели.
#
# Для начала предлагаем вспомнить некоторые функции и определения из NumPy.
#
# Векторы и матрицы — это объекты, которыми приходится оперировать в глубоком обучении. NumPy предоставляет функции для таких операций.

# %% [markdown]
# Скачать ноутбук (https://github.com/luhakv/cv_engr/blob/master/1._numpy_screencast.ipynb)

# %% [markdown]
# Вспомним основные функции NumPy:
#
# 1) import numpy as np — импорт библиотеки;
#
# 2) Создание векторов и матриц:
# - numpy.zeros() — создание нулевого массива;
# - numpy.random — создание массива со случайными элементами;
# - numpy.linspace() — генерация последовательности данных, равномерно расположенных на числовой прямой на заданном интервале;
# - numpy.array() — функция, создающая массив.
#
# 3) Различные математические операции: .mean(), .sum(), .max().
# 4) numpy.reshape — изменение формы массива.

# %% [markdown]
# ### Задание 2.1
#
# Имеется вектор x. Какую функцию надо применить, чтобы сделать из x вектор-столбец?

# %%
x = np.arange(1, 10)
print(x)

# %% [markdown]
# Ответ: x.reshape(-1, 1)
#
# ### Задание 2.2
#
# Если вы не знаете ответа, напишите в поле «не знаю ответ».
#
# Имеется некоторая матрица A. Используя np.equal(), проверьте, равна ли матрица себе транспонированной. В ответ запишите код.
# Ответ: np.equal(A, A.T).all()

# %% [markdown]
# ### Задание 2.3
#
# Используя np.dot(), напишите функцию calc_kxb, которая принимает на вход k, b, x и возвращает результат операции  для трёхмерного массива.
#
# В ответ запишите результат выполнения функции при таких значениях переменных:

# %%
k = np.array([1, 5, 10])
b = 3
x = np.array([1,2,3])
calc_kxb(k,x,b)

# %% [markdown]
# Ответ: 44

# %% [markdown]
# ### Задание 2.4
#
# Имеется одномерный массив a. Как развернуть этот массив с помощью среза?
# Ответ: a[::-1]

# %% [markdown]
# ###  3. Линейные модели
#
# ### ВСПОМИНАЕМ ЛИНЕЙНЫЕ МОДЕЛИ
#
# ⛏ Вы уже познакомились с линейными моделями машинного обучения в предыдущих разделах и представляете, зачем они нужны и как работают.
#
# Для начала вспомним некоторые теоретические представления о линейной регрессии.
#
# ### Задание 3.1
#
# Какие ограничения накладываются на данные для применения линейной регрессии?
# ОТвет: Только линейная связь в данных
#
# ### Задание 3.2
# Какой механизм, как правило, лежит в основе модели линейной регрессии?
# Ответ: Метод наименьших квадратов
#
# ### Задание 3.3
# Входные данные для регрессии называются регрессорами. Сколько может быть регрессоров и параметров у модели?
# Ответ: любое N регрессоров, N+1 параметров
#
# ### РЕАЛИЗАЦИЯ ЛИНЕЙНОЙ РЕГРЕССИИ
#
# Давайте вспомним и имплементируем линейную регрессию, достаточно простую и эффективную модель — пусть это будет отправной точкой в нашем пути.
#
# Для начала выберем линейную функцию и сгенерируем выборку, которая ей соответствует.
#
# Это выглядит достаточно простой задачей, которую можно решить в уме, и мы уже знаем, как её решать с помощью Python и sklearn. Но теперь мы хотим понять, что у неё «под капотом».
#
# Мы знаем, что, по сути, это та же линейная функция, которая умеет найти нужный коэффициент на основе тех данных, которые мы ей показали. Создадим свою модель линейной регрессии:
#
# Скачать ноутбук: https://github.com/luhakv/cv_engr/blob/master/2._regression1_screencast.ipynb

# %% [markdown]
# ### Задание 3.4
#
# Давайте посчитаем руками — найдём линейную функцию сами.
# Есть точки (1,7), (-1,0), (3,14). Посчитайте k и b.
#
# Подсказка (1 из 1): Можно взять любые две точки и из той, которая правее, вычесть левую, затем разделить получившийся y на получившийся x и таким образом получить k. Подставив получившийся k и одну из точек в уравнение y=kx+b, можно найти b.
#
# Ответ: 3.5,.*3.5

# %% [markdown]
# ### Задание 3.5
# Сколько точек достаточно для того, чтобы посчитать коэффициент линейной функции?
# Ответ: 2
#
# ### Задание 3.6
# Почему для линейной регрессии мы можем взять любое количество точек?
# Ответ: Данные далеко не всегда чистые и поэтому не лежат на одной прямой, мы не можем приравнять ошибку к нулю — только минимизировать верно

# %% [markdown]
# ### МЕТОД НАИМЕНЬШИХ КВАДРАТОВ
#
# Каким образом линейная регрессия подбирает нужные коэффициенты?
#
# Скачать ноутбук: https://github.com/luhakv/cv_engr/blob/master/Module_2_Screencast_3.ipynb

# %% [markdown]
# Обычно задачу линейной регрессии решают с помощью метода наименьших квадратов (SSE — Sum of Squared Errors): в нём мы минимизируем функцию суммы квадратов ошибки.
#
# Мы знаем, что это квадратичная функция, поэтому можем взять производную и приравнять её к нулю, тем самым найдя локальный минимум нашей функции.
#
# Далее из полученной системы уравнений мы можем выразить k и b — решения системы, значения, при которых достигается минимум. В нашем случае он единственный, то есть минимум не только локальный, но и глобальный.
#
# Теперь наша задача — получить точки, подставить их в заданные формулы и тем самым научить нашу модель правильно предсказывать результат.
#
# ### Задание 3.7
#
# Почему в методе наименьших квадратов локальный минимум один?
# Ответ:  Функция квадратичная, имеет вид параболы

# %% [markdown]
# ### Задание 3.8
#
# За что отвечает K в формуле метода наименьших квадратов?
# Наклон прямой
#
# За что отвечает b в формуле метода наименьших квадратов?
# Сдвиг прямой
#
# ### Задание 3.9
#
# Почему мы приравниваем производную к нулю?
# По свойству производной: экстремум функции находится в нуле производной

# %% [markdown]
# ### 4. Градиентный спуск
#
# ### СУТЬ ГРАДИЕНТНОГО СПУСКА
#
# Градиентный спуск — метод нахождения локального минимума или максимума функции с помощью градиента.
# Его замечательное свойство заключается в том, что он указывает на локальный максимум функции из заданной точки. Иными словами, он показывает туда, где функция быстрее всего растёт.
#
# ![nlp_u1_md2_4_2.png](attachment:nlp_u1_md2_4_2.png)
#
# Это значит, что, «двигаясь» в сторону градиента, мы приближаемся к максимуму функции.
#
# Также, используя антиградиент, мы можем найти локальный минимум.
#
# ![nlp_u1_md2_4_3.png](attachment:nlp_u1_md2_4_3.png)
#
# ### РАСЧЁТ ГРАДИЕНТОВ РУКАМИ
#
# Уметь считать производные руками иногда приходится для того, чтобы запрограммировать расчёт градиентов для функций.
