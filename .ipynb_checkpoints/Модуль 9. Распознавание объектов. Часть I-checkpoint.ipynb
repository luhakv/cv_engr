# %% [markdown]
# ## Трек «CV-инженер»
# ### Skillfactory: DSPR-19
# ### Модуль 9. Распознавание объектов. Часть I

# %% [markdown]
# ### 1. Что вас ждёт в этом модуле?
#
# ⛏ В прошлых модулях вы научились использовать продвинутые модели глубокого обучения для решения задачи классификации изображений и даже применили перенос обучения для распознавания IT-знаменитостей.
#
# Помимо классификации изображений, распознаванием именуются также локализация и обнаружение объекта.
#
# Этот модуль посвящён подробному знакомству с задачами распознавания объектов.
#
# ### В ЭТОМ МОДУЛЕ МЫ РАЗБЕРЁМ:
#
# - чем отличаются задачи классификации, локализации и обнаружения;
#
# - что такое одноэтапные и двухэтапные детекторы объектов глубокого обучения;
#
# - где применяется распознавание объектов;
#
# - как устроены архитектуры R-CNN и YOLO.
#
# ### ВЫ НАУЧИТЕСЬ:
#
# - имплементировать сети семейств R-CNN и YOLO.
#
# МАТЕРИАЛЫ МОДУЛЯ ПОДГОТОВИЛИ:
#
# ЕКАТЕРИНА ТРОФИМОВА
#
# Стажёр-исследователь, аспирант
#
# Научно-учебная лаборатория методов анализа больших данных, НИУ ВШЭ
#
# Проект «Использование графовых нейронных сетей для реконструкции электромагнитных ливней в нейтринных экспериментах»
